# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Temp Máx

# %%
df = pd.read_excel('graps.xlsx')

# %%
df = df.set_index('Date')

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
fig, ax = plt.subplots(5, 1, sharex=True, sharey=True, figsize=(10, 20))
#ax[4].tick_params(axis='both', which='major', labelsize=11)
#ax[4].tick_params(axis='both', which='minor', labelsize=10)
fig.text(0.06, 0.5, 'Temperatura (°C)', ha='center',
         va='center', rotation='vertical', fontsize=15)
#fig.text(0.5, 0.11, 'Data', ha='center', va='center',fontsize = 12)
ax[0].set_title('LDAPS')
sns.lineplot(ax=ax[0], data=df[['Previsão LDAPS', 'Temperatura Real']])
ax[1].set_title('SVR')
sns.lineplot(ax=ax[1], data=df[['Previsão SVR', 'Temperatura Real']])
ax[2].set_title('RF')
sns.lineplot(ax=ax[2], data=df[['Previsão RF', 'Temperatura Real']])
ax[3].set_title('MLP')
sns.lineplot(ax=ax[3], data=df[['Previsão MLP', 'Temperatura Real']])
ax[4].set_title('MME')
ax[4].set_xlabel('Data', fontsize=15)
sns.lineplot(ax=ax[4], data=df[['Previsão MME', 'Temperatura Real']])
# Out:
# <AxesSubplot:title={'center':'MME'}, xlabel='Data'>

# %% [markdown]
# ## Temp Min

# %%
df = pd.read_excel('graps.xlsx',sheet_name='temp_min')
df = df.set_index('Date')

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
fig, ax = plt.subplots(5, 1, sharex=True, sharey=True, figsize=(10, 20))
#ax[4].tick_params(axis='both', which='major', labelsize=11)
#ax[4].tick_params(axis='both', which='minor', labelsize=10)
fig.text(0.06, 0.5, 'Temperatura (°C)', ha='center',
         va='center', rotation='vertical', fontsize=15)
#fig.text(0.5, 0.11, 'Data', ha='center', va='center',fontsize = 12)
ax[0].set_title('LDAPS')
sns.lineplot(ax=ax[0], data=df[['Previsão LDAPS', 'Temperatura Real']])
ax[1].set_title('SVR')
sns.lineplot(ax=ax[1], data=df[['Previsão SVR', 'Temperatura Real']])
ax[2].set_title('RF')
sns.lineplot(ax=ax[2], data=df[['Previsão RF', 'Temperatura Real']])
ax[3].set_title('MLP')
sns.lineplot(ax=ax[3], data=df[['Previsão MLP', 'Temperatura Real']])
ax[4].set_title('MME')
ax[4].set_xlabel('Data', fontsize = 15)
sns.lineplot(ax=ax[4], data=df[['Previsão MME', 'Temperatura Real']])
# Out:
# <AxesSubplot:title={'center':'MME'}, xlabel='Data'>
